# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Understanding The Data

# %% [markdown]
# ### Loading The Datasets

# %%
df_fulfill=pd.read_csv('Fulfillment.csv')
df_fulfill.sample(10)
# Out:
#                                       Product Name  \
# 36                       Clicgear Rovic Cooler Bag
# 3                Nike Men's Free 5.0+ Running Shoe
# 87               Garmin Approach S3 Golf GPS Watch
# 105                    Pelican Maverick 100X Kayak
# 67       LIJA Women's Mid-Length Panel Golf Shorts
# 18   Glove It Women's Mod Oval 3-Zip Carry All Gol
# 52              Under Armour Kids' Mercenary Slide
# 40   Titleist Pro V1 High Numbers Personalized Gol
# 72         Nike Men's Free TR 5.0 TB Training Shoe
# 27            Hirzl Women's Soffft Flex Golf Glove
#
#       Warehouse Order Fulfillment (days)
# 36                                    6.5
# 3                                     9.4
# 87                                    4.5
# 105                                   2.3
# 67                                    8.0
# 18                                    3.3
# 52                                    4.2
# 40                                    3.3
# ...

# %%
df_inv=pd.read_csv('Inventory.csv')
df_inv.sample(10)
# Out:
#                                        Product Name   Year Month   \
# 152                      TYR Boys' Team Digi Jammer        201711
# 2242               Perfect Fitness Perfect Rip Deck        201605
# 3477                                     Web Camera        201507
# 3650              GoPro HERO3+ Black Edition Camera        201506
# 1154       Mio ALPHA Heart Rate Monitor/Sport Watch        201703
# 1509             TaylorMade 2017 Purelite Stand Bag        201612
# 2686  Merrell Women's Siren Mid Waterproof Hiking B        201602
# 1815             Under Armour Men's Tech II T-Shirt        201609
# 872      Team Golf New England Patriots Putter Grip        201705
# 3054                    Polar Loop Activity Tracker        201511
#
#        Warehouse Inventory   Inventory Cost Per Unit
# 152                       0                  1.29350
# 2242                    884                  2.13911
# 3477                      0                  2.16093
# ...

# %%
df_order=pd.read_csv('Orders_and_shipments.csv', encoding='latin1')
df_order.sample(10)
df_order.sample(10)
# Out:
#         Order ID    Order Item ID    Order YearMonth    Order Year   \
# 17230       29373            73486             201603          2016
# 30132       55528           138878             201703          2017
# 18163       63086           157728             201707          2017
# 24016       31226            78038             201603          2016
# 1437        25215            63196             201601          2016
# 3864        61665           154168             201706          2017
# 13701       29888            74782             201603          2016
# 27134       37561            93753             201510          2015
# 25095        6338            15861             201504          2015
# 12238       63506           158754             201511          2015
#
#         Order Month    Order Day  Order Time  Order Quantity  \
# 17230              3            4      18:19               1
# 30132              3           21      13:34               1
# ...

# %%
df_fulfill.isna().sum()
# Out:
# Product Name                            0
#  Warehouse Order Fulfillment (days)     0
# dtype: int64

# %%
df_fulfill.shape
# Out:
# (118, 2)

# %%
df_inv['Year']=df_inv[' Year Month '].apply(lambda x:int(str(x)[:4]))
df_inv['Month']=df_inv[' Year Month '].apply(lambda x:int(str(x)[4:]))
df_inv.drop(columns=' Year Month ',inplace=True)
df_inv
# Out:
#                                        Product Name   Warehouse Inventory   \
# 0                  Perfect Fitness Perfect Rip Deck                      0
# 1              Nike Men's Dri-FIT Victory Golf Polo                      2
# 2                  O'Brien Men's Neoprene Life Vest                      0
# 3                 Nike Men's Free 5.0+ Running Shoe                      1
# 4     Under Armour Girls' Toddler Spine Surge Runni                      0
# ...                                             ...                    ...
# 4195             TaylorMade 2017 Purelite Stand Bag                      0
# 4196                           Ogio Race Golf Shoes                      0
# 4197                        GolfBuddy VT3 GPS Watch                      0
# 4198            Titleist Small Wheeled Travel Cover                      0
# 4199                    Polar Loop Activity Tracker                      1
#
#       Inventory Cost Per Unit  Year  Month
# ...
